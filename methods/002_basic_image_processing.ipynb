# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("../inpdata/images/RGBY.png", 1)

# %%
print(img.shape)
print(img.dtype)
# Out:
# (800, 1280, 3)
# uint8

# %%
fig = plt.figure(figsize=(5, 5))
plt.imshow(img)

# %%
plt.imshow(img[0:10, 10:30])
